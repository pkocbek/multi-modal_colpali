# %% [markdown]
# ## Evaluation visual-retrivers (CI 95%)

# %%
import pandas as pd
from functions import (
    run_ci_summary,
    DEFAULT_PRICE_DICT,
    get_metric_descriptions,
)

# %%
TOPK_CONFIG = {
    5: {
        'data_path': 'results/evals_topk5/',
        'summary_path': 'results/summary_CI_topk5.xlsx',
    },
    10: {
        'data_path': 'evals/evals_topk10/',
        'summary_path': 'results/summary_CI_topk10.xlsx',
    },
}

TOP_K = 5
CONFIG = TOPK_CONFIG[TOP_K]
DATA_PATH = CONFIG['data_path']
SUMMARY_FILE = CONFIG['summary_path']
PRECISION_LABEL = f'P@{TOP_K}'

GROUP_BY_COLS = ['Model', 'Model_ret', 'Difficulty']
MODEL_ORDER = ['gpt-5', 'gpt-5-mini', 'gpt-5-nano']
RETRIEVER_ORDER = [
    'vidore/colpali-v1.3-merged',
    'vidore/colqwen2.5-v0.2',
    'ahmed-masry/ColFlor',
]
DISPLAY_COLUMNS = [
    'Cor_answer',
    'Elapsed',
    'Total_tokens',
    PRECISION_LABEL,
    'Throughput',
    'Cost',
    'Price-per-cost',
]
GROUP_BY_NO_DIFFICULTY = [col for col in GROUP_BY_COLS if col != 'Difficulty']
metric_descriptions = get_metric_descriptions(TOP_K)

# %%
per_iteration_summary, summary_table, merged_df = run_ci_summary(
    path=DATA_PATH,
    group_by_cols=GROUP_BY_COLS,
    price_dict=DEFAULT_PRICE_DICT,
    top_k=TOP_K,
    model_order=MODEL_ORDER,
    retriever_order=RETRIEVER_ORDER,
    precision_label=PRECISION_LABEL,
)
summary_table_display = summary_table[GROUP_BY_COLS + DISPLAY_COLUMNS]

# %%
per_iteration_summary
# Out:
#          Model                   Model_ret Difficulty  Iteration  Cor_answer  \
# 0        gpt-5  vidore/colpali-v1.3-merged       Easy          1    0.840580
# 1        gpt-5  vidore/colpali-v1.3-merged       Easy          2    0.797101
# 2        gpt-5  vidore/colpali-v1.3-merged       Hard          1    0.833333
# 3        gpt-5  vidore/colpali-v1.3-merged       Hard          2    0.833333
# 4        gpt-5  vidore/colpali-v1.3-merged     Medium          1    0.777778
# ..         ...                         ...        ...        ...         ...
# 67  gpt-5-nano         ahmed-masry/ColFlor       Hard          2    0.666667
# 68  gpt-5-nano         ahmed-masry/ColFlor       Hard          3    0.500000
# 69  gpt-5-nano         ahmed-masry/ColFlor     Medium          1    0.777778
# 70  gpt-5-nano         ahmed-masry/ColFlor     Medium          2    0.777778
# 71  gpt-5-nano         ahmed-masry/ColFlor     Medium          3    0.740741
#
#       Elapsed  Total_tokens       P@5   Throughput      Cost  Correct_answers  \
# 0   10.029332   4555.724638  0.058824   653.810501  3.143450               58
# 1   30.978978   4621.304348  0.029412   157.093342  3.188700               55
# 2    7.397494   5065.541667  0.040000   752.635570  1.215730               20
# 3   32.467337   5010.250000  0.030000   159.340461  1.202460               20
# 4    7.010341   4360.037037  0.041667   679.059857  1.177210               21
# ..        ...           ...       ...          ...       ...              ...
# 67   4.639456   9984.625000  0.020000  2221.975524  0.095852               16
# 68   5.943199  10029.916667  0.020000  1888.748617  0.096287               12
# 69  28.346568  10339.851852  0.033333   374.110352  0.111670               21
# 70   5.282243  10292.333333  0.033333  1962.479722  0.111157               21
# 71   6.975807  10503.407407  0.033333  1636.891080  0.113437               20
#
#     Price-per-cost
# 0         5.419741
# 1         5.797636
# 2         6.078650
# 3         6.012300
# 4         5.605762
# ..             ...
# 67        0.599078
# 68        0.802393
# 69        0.531764
# 70        0.529320
# 71        0.567184
#
# [72 rows x 12 columns]

# %%
summary_table_display
# Out:
#          Model                   Model_ret Difficulty             Cor_answer  \
# 0        gpt-5  vidore/colpali-v1.3-merged       Easy  0.819\n[0.213, 1.000]
# 1        gpt-5  vidore/colpali-v1.3-merged       Hard  0.833\n[0.219, 1.000]
# 2        gpt-5  vidore/colpali-v1.3-merged     Medium  0.778\n[0.197, 0.993]
# 3        gpt-5      vidore/colqwen2.5-v0.2       Easy  0.845\n[0.294, 1.000]
# 4        gpt-5      vidore/colqwen2.5-v0.2       Hard  0.792\n[0.266, 0.990]
# 5        gpt-5      vidore/colqwen2.5-v0.2     Medium  0.827\n[0.285, 1.000]
# 6        gpt-5         ahmed-masry/ColFlor       Easy  0.797\n[0.205, 0.999]
# 7        gpt-5         ahmed-masry/ColFlor       Hard  0.854\n[0.228, 1.000]
# 8        gpt-5         ahmed-masry/ColFlor     Medium  0.833\n[0.219, 1.000]
# 9   gpt-5-mini  vidore/colpali-v1.3-merged       Easy  0.845\n[0.294, 1.000]
# 10  gpt-5-mini  vidore/colpali-v1.3-merged       Hard  0.806\n[0.273, 0.995]
# 11  gpt-5-mini  vidore/colpali-v1.3-merged     Medium  0.827\n[0.285, 1.000]
# 12  gpt-5-mini      vidore/colqwen2.5-v0.2       Easy  0.841\n[0.292, 1.000]
# 13  gpt-5-mini      vidore/colqwen2.5-v0.2       Hard  0.653\n[0.196, 0.938]
# 14  gpt-5-mini      vidore/colqwen2.5-v0.2     Medium  0.840\n[0.291, 1.000]
# 15  gpt-5-mini         ahmed-masry/ColFlor       Easy  0.812\n[0.211, 1.000]
# 16  gpt-5-mini         ahmed-masry/ColFlor       Hard  0.792\n[0.203, 0.997]
# 17  gpt-5-mini         ahmed-masry/ColFlor     Medium  0.778\n[0.197, 0.993]
# 18  gpt-5-nano  vidore/colpali-v1.3-merged       Easy  0.778\n[0.258, 0.985]
# 19  gpt-5-nano  vidore/colpali-v1.3-merged       Hard  0.611\n[0.176, 0.922]
# 20  gpt-5-nano  vidore/colpali-v1.3-merged     Medium  0.753\n[0.246, 0.976]
# 21  gpt-5-nano      vidore/colqwen2.5-v0.2       Easy  0.758\n[0.248, 0.978]
# 22  gpt-5-nano      vidore/colqwen2.5-v0.2       Hard  0.542\n[0.144, 0.893]
# 23  gpt-5-nano      vidore/colqwen2.5-v0.2     Medium  0.704\n[0.221, 0.958]
# 24  gpt-5-nano         ahmed-masry/ColFlor       Easy  0.773\n[0.256, 0.983]
# 25  gpt-5-nano         ahmed-masry/ColFlor       Hard  0.569\n[0.156, 0.904]
# 26  gpt-5-nano         ahmed-masry/ColFlor     Medium  0.765\n[0.252, 0.981]
#
#                   Elapsed                 Total_tokens                    P@5  \
# 0   20.50\n[0.00, 153.60]     4588.5\n[4171.9, 5005.1]  0.044\n[0.000, 0.231]
# 1   19.93\n[0.00, 179.20]     5037.9\n[4686.6, 5389.2]  0.035\n[0.000, 0.099]
# 2   19.31\n[0.00, 175.57]     4431.4\n[3524.1, 5338.8]  0.033\n[0.000, 0.139]
# 3    22.89\n[0.00, 81.84]     4296.2\n[4177.7, 4414.7]  0.065\n[0.045, 0.084]
# 4    23.11\n[0.00, 83.48]     4633.5\n[4407.5, 4859.6]  0.053\n[0.039, 0.068]
# 5    22.15\n[0.00, 78.91]     4392.3\n[4249.0, 4535.6]  0.006\n[0.000, 0.029]
# 6   18.02\n[0.00, 154.33]     4570.6\n[4181.4, 4959.7]  0.041\n[0.041, 0.041]
# 7   16.37\n[0.00, 141.62]     4878.2\n[4522.4, 5234.0]  0.020\n[0.020, 0.020]
# 8   18.63\n[0.00, 154.54]     4544.6\n[4333.6, 4755.7]  0.033\n[0.033, 0.033]
# 9    13.85\n[0.00, 44.10]     7764.9\n[7212.1, 8317.7]  0.042\n[0.021, 0.063]
# 10   14.26\n[0.00, 48.99]     7874.4\n[6572.2, 9176.6]  0.040\n[0.000, 0.090]
# 11   13.26\n[0.00, 41.85]     7766.7\n[7101.2, 8432.2]  0.050\n[0.000, 0.112]
# 12   24.26\n[0.00, 88.52]     8827.4\n[8681.5, 8973.3]  0.063\n[0.052, 0.074]
# 13   24.45\n[0.00, 90.60]     9202.7\n[9031.5, 9373.8]  0.050\n[0.050, 0.050]
# 14   24.46\n[0.00, 91.19]     8908.4\n[8821.2, 8995.6]  0.008\n[0.000, 0.029]
# 15   21.72\n[0.00, 89.65]     7604.4\n[7498.3, 7710.6]  0.041\n[0.041, 0.041]
# 16   19.68\n[0.00, 75.96]     7202.4\n[6778.6, 7626.2]  0.020\n[0.020, 0.020]
# 17   21.81\n[0.00, 83.66]     7910.8\n[7880.7, 7940.9]  0.033\n[0.033, 0.033]
# 18   14.12\n[0.00, 48.75]     9634.7\n[9303.8, 9965.7]  0.055\n[0.027, 0.083]
# 19   13.64\n[0.00, 43.99]   10439.2\n[8831.3, 12047.0]  0.023\n[0.000, 0.061]
# 20   14.39\n[0.00, 50.35]   10141.6\n[9735.9, 10547.3]  0.033\n[0.033, 0.033]
# 21   23.44\n[0.00, 77.03]  11601.0\n[11469.2, 11732.9]  0.066\n[0.055, 0.077]
# 22   23.57\n[0.00, 79.67]  12255.7\n[12200.0, 12311.4]  0.053\n[0.039, 0.068]
# 23   24.30\n[0.00, 81.46]  11705.7\n[11689.5, 11722.0]  0.011\n[0.000, 0.023]
# 24   13.11\n[0.00, 44.53]     9927.2\n[9916.6, 9937.8]  0.041\n[0.041, 0.041]
# 25   12.45\n[0.00, 43.28]    9941.1\n[9650.9, 10231.3]  0.020\n[0.020, 0.020]
# 26   13.53\n[0.00, 45.47]  10378.5\n[10103.5, 10653.6]  0.033\n[0.033, 0.033]
#
#                Throughput                Cost      Price-per-cost
# 0    405.5\n[0.0, 3561.1]  3.17\n[2.88, 3.45]  5.61\n[3.21, 8.01]
# 1    456.0\n[0.0, 4225.3]  1.21\n[1.12, 1.29]  6.05\n[5.62, 6.47]
# 2    415.8\n[0.0, 3761.3]  1.20\n[0.95, 1.44]  5.70\n[4.53, 6.86]
# 3     353.5\n[0.0, 931.5]  2.96\n[2.88, 3.05]  5.08\n[4.82, 5.34]
# 4    382.6\n[0.0, 1000.3]  1.11\n[1.06, 1.17]  5.85\n[5.57, 6.14]
# 5    384.0\n[0.0, 1005.6]  1.19\n[1.15, 1.22]  5.31\n[4.95, 5.67]
# 6    420.4\n[0.0, 3678.7]  3.15\n[2.89, 3.42]  5.74\n[4.90, 6.57]
# 7    507.6\n[0.0, 4422.6]  1.17\n[1.09, 1.26]  5.72\n[3.53, 7.90]
# 8    390.5\n[0.0, 3355.5]  1.23\n[1.17, 1.28]  5.46\n[4.17, 6.74]
# 9    939.2\n[0.0, 2336.2]  1.07\n[1.00, 1.15]  1.84\n[1.64, 2.04]
# 10  1004.8\n[0.0, 2577.3]  0.38\n[0.32, 0.44]  1.97\n[1.29, 2.65]
# 11   984.5\n[0.0, 2395.4]  0.42\n[0.38, 0.46]  1.88\n[1.61, 2.14]
# 12   726.5\n[0.0, 1952.9]  1.22\n[1.20, 1.24]  2.10\n[1.91, 2.29]
# 13   789.2\n[0.0, 2144.0]  0.44\n[0.43, 0.45]  2.84\n[2.11, 3.56]
# 14   794.6\n[0.0, 2228.3]  0.48\n[0.48, 0.49]  2.13\n[1.76, 2.50]
# 15   379.6\n[0.0, 1495.2]  1.05\n[1.03, 1.06]  1.87\n[1.42, 2.33]
# 16   409.7\n[0.0, 1239.7]  0.35\n[0.33, 0.37]  1.82\n[1.71, 1.93]
# 17   391.1\n[0.0, 1403.7]  0.43\n[0.43, 0.43]  2.03\n[2.03, 2.04]
# 18  1282.1\n[0.0, 3431.4]  0.27\n[0.26, 0.28]  0.50\n[0.42, 0.58]
# 19  1278.3\n[0.0, 3280.1]  0.10\n[0.08, 0.12]  0.69\n[0.61, 0.76]
# 20  1292.6\n[0.0, 3398.7]  0.11\n[0.11, 0.11]  0.54\n[0.49, 0.59]
# 21   849.6\n[0.0, 2304.3]  0.32\n[0.32, 0.32]  0.61\n[0.57, 0.65]
# 22   938.8\n[0.0, 2580.7]  0.12\n[0.12, 0.12]  0.91\n[0.74, 1.08]
# 23   847.6\n[0.0, 2327.6]  0.13\n[0.13, 0.13]  0.67\n[0.58, 0.75]
# 24  1332.5\n[0.0, 3426.4]  0.27\n[0.27, 0.27]  0.51\n[0.45, 0.57]
# 25  1495.3\n[0.0, 3940.4]  0.10\n[0.09, 0.10]  0.71\n[0.45, 0.96]
# 26  1324.5\n[0.0, 3408.7]  0.11\n[0.11, 0.12]  0.54\n[0.49, 0.60]

# %%
if 'Difficulty' in GROUP_BY_COLS:
    summary_table.set_index(GROUP_BY_COLS)[DISPLAY_COLUMNS].unstack('Difficulty')

# %%
summary_table_no_diff = None
if GROUP_BY_NO_DIFFICULTY != GROUP_BY_COLS:
    per_iteration_no_diff, summary_table_no_diff, _ = run_ci_summary(
        path=DATA_PATH,
        group_by_cols=GROUP_BY_NO_DIFFICULTY,
        price_dict=DEFAULT_PRICE_DICT,
        top_k=TOP_K,
        model_order=MODEL_ORDER,
        retriever_order=RETRIEVER_ORDER,
        dataframe=merged_df,
        precision_label=PRECISION_LABEL,
    )
    summary_table_no_diff = summary_table_no_diff[GROUP_BY_NO_DIFFICULTY + DISPLAY_COLUMNS]
summary_table_no_diff
# Out:
#         Model                   Model_ret             Cor_answer  \
# 0       gpt-5  vidore/colpali-v1.3-merged  0.812\n[0.211, 1.000]
# 1       gpt-5      vidore/colqwen2.5-v0.2  0.831\n[0.286, 1.000]
# 2       gpt-5         ahmed-masry/ColFlor  0.817\n[0.213, 1.000]
# 3  gpt-5-mini  vidore/colpali-v1.3-merged  0.833\n[0.288, 1.000]
# 4  gpt-5-mini      vidore/colqwen2.5-v0.2  0.803\n[0.272, 0.994]
# 5  gpt-5-mini         ahmed-masry/ColFlor  0.800\n[0.206, 1.000]
# 6  gpt-5-nano  vidore/colpali-v1.3-merged  0.739\n[0.238, 0.971]
# 7  gpt-5-nano      vidore/colqwen2.5-v0.2  0.703\n[0.220, 0.958]
# 8  gpt-5-nano         ahmed-masry/ColFlor  0.731\n[0.234, 0.968]
#
#                  Elapsed                 Total_tokens                    P@5  \
# 0  20.12\n[0.00, 163.66]     4643.1\n[4269.6, 5016.5]  0.040\n[0.000, 0.188]
# 1   22.77\n[0.00, 81.50]     4385.3\n[4273.7, 4496.9]  0.050\n[0.034, 0.066]
# 2  17.83\n[0.00, 151.84]     4626.3\n[4378.9, 4873.7]  0.036\n[0.036, 0.036]
# 3   13.80\n[0.00, 44.56]     7787.2\n[7112.3, 8462.1]  0.043\n[0.034, 0.053]
# 4   24.34\n[0.00, 89.54]     8920.7\n[8867.9, 8973.4]  0.049\n[0.038, 0.060]
# 5   21.33\n[0.00, 85.57]     7593.0\n[7562.5, 7623.5]  0.036\n[0.036, 0.036]
# 6   14.09\n[0.00, 48.16]    9909.7\n[9408.4, 10411.0]  0.045\n[0.021, 0.068]
# 7   23.66\n[0.00, 78.55]  11755.5\n[11688.7, 11822.3]  0.052\n[0.047, 0.056]
# 8   13.07\n[0.00, 44.49]   10031.6\n[9928.9, 10134.2]  0.036\n[0.036, 0.036]
#
#               Throughput                Cost      Price-per-cost
# 0   417.9\n[0.0, 3739.0]  5.57\n[5.12, 6.02]  5.72\n[4.14, 7.29]
# 1    366.2\n[0.0, 960.9]  5.26\n[5.13, 5.40]  5.28\n[5.08, 5.48]
# 2   431.1\n[0.0, 3754.7]  5.55\n[5.25, 5.85]  5.66\n[5.36, 5.97]
# 3   962.5\n[0.0, 2396.8]  1.87\n[1.71, 2.03]  1.87\n[1.59, 2.15]
# 4   754.3\n[0.0, 2050.2]  2.14\n[2.13, 2.15]  2.23\n[1.98, 2.47]
# 5   388.2\n[0.0, 1423.5]  1.82\n[1.81, 1.83]  1.90\n[1.65, 2.14]
# 6  1283.7\n[0.0, 3391.7]  0.48\n[0.45, 0.50]  0.54\n[0.48, 0.59]
# 7   867.0\n[0.0, 2364.7]  0.56\n[0.56, 0.57]  0.67\n[0.62, 0.72]
# 8  1363.3\n[0.0, 3523.5]  0.48\n[0.48, 0.49]  0.55\n[0.48, 0.62]

# %%
merged_df
# Out:
#       Unnamed: 0  Question_nr  Paper_id  Nr_data_suppl  \
# 0              0           38  Paper_07            1.0
# 1              1           41  Paper_08            1.0
# 2              2            3  Paper_01            1.0
# 3              3           50  Paper_09            1.0
# 4              4          103  Paper_19            NaN
# ...          ...          ...       ...            ...
# 2875         115           66  Paper_12            1.0
# 2876         116           53  Paper_10            1.0
# 2877         117           14  Paper_03            1.0
# 2878         118            1  Paper_01            1.0
# 2879         119          102  Paper_19            NaN
#
#                                                  doi  \
# 0        https://doi.org/10.1172%2Fjci.insight.89703
# 1       https://doi.org/10.1016%2Fj.isci.2022.103897
# 2         https://doi.org/10.1038/s41590-024-01916-8
# 3                https://doi.org/10.1002%2Fart.39273
# 4              https://doi.org/10.1093/gerona/glt190
# ...                                              ...
# 2875  https://doi.org/10.1053%2Fj.gastro.2018.01.002
# 2876    https://doi.org/10.1016/j.bbadis.2018.03.018
# 2877    https://doi.org/10.1097/hjh.0000000000002963
# 2878      https://doi.org/10.1038/s41590-024-01916-8
# 2879           https://doi.org/10.1093/gerona/glt190
#
#                                                   title  \
# 0     Estrogens regulate glycosylation of IgG in wom...
# 1     Immunoglobulin G glycome composition in transi...
# 2     A unique serum IgG glycosylation signature pre...
# 3     Association of Systemic Lupus Erythematosus Wi...
# 4     Glycans Are a Novel Biomarker of Chronological...
# ...                                                 ...
# 2875  Glycosylation of Immunoglobulin G Associates W...
# 2876   Low galactosylation of IgG associates with hi...
# 2877  N-glycosylation of immunoglobulin G predicts i...
# 2878  A unique serum IgG glycosylation signature pre...
# 2879  Glycans Are a Novel Biomarker of Chronological...
#
#                                                question  \
# 0     Which IgG glycan trait increases in women at 5...
# 1     Using single-point measurements of IgG glycans...
# 2     Which IgG glycan changes are seen in people wi...
# 3     The predictive model for systemic lupus erythe...
# 4     Which monosaccharide does the letter “A” repre...
# ...                                                 ...
# 2875  On IgG glycans, sialic acid is connected to ga...
# 2876  In 1985, Parekh et al. showed that IgG glycans...
# 2877  Which annotation is used to describe core fuco...
# 2878  How many different glycan variations have been...
# 2879  Which IgG glycan trait shows the strongest ass...
#
#                               A                          B  \
# 0                         G0/G2                     G0F/G2
# 1                         0.776                      0.789
# 2     decreased galactosylation  increased galactosylation
# 3             African Caribbean             Latin American
# 4           N-acetylglucosamine                  Galactose
# ...                         ...                        ...
# 2875       α1,6 glycosidic bond       α2,6 glycosidic bond
# 2876       High galactosylation        Low galactosylation
# 2877                       FA2B                     FA2BG2
# 2878                    Over 60                    Over 30
# 2879            Galactosylation                Sialylation
#
#                           C  ...    Elapsed Total_tokens    Time_start  \
# 0                     G0/G1  ...  31.983248        11199  1.763008e+09
# 1                     0.853  ...  20.979322         9044  1.763008e+09
# 2     increased sialylation  ...  31.977889         9827  1.763008e+09
# 3               Han Chinese  ...  21.976458         9129  1.763008e+09
# 4                    Fucose  ...  21.975137         9485  1.763008e+09
# ...                     ...  ...        ...          ...           ...
# 2875   β1,2 glycosidic bond  ...  18.540669         7905  1.763023e+09
# 2876       High sialylation  ...  17.539433         7642  1.763023e+09
# 2877              FA2[3]BG1  ...  10.538190         5779  1.763023e+09
# 2878                Over 40  ...  18.536889         7992  1.763023e+09
# 2879      Core fucosylation  ...  16.535234         6954  1.763023e+09
#
#         Time_end                                            Metrics  \
# 0     1763008511  CompletionUsage(completion_tokens=1044, prompt...
# 1     1763008500  CompletionUsage(completion_tokens=850, prompt_...
# 2     1763008511  CompletionUsage(completion_tokens=531, prompt_...
# 3     1763008501  CompletionUsage(completion_tokens=979, prompt_...
# 4     1763008501  CompletionUsage(completion_tokens=2067, prompt...
# ...          ...                                                ...
# 2875  1763022615  CompletionUsage(completion_tokens=402, prompt_...
# 2876  1763022614  CompletionUsage(completion_tokens=146, prompt_...
# 2877  1763022607  CompletionUsage(completion_tokens=658, prompt_...
# 2878  1763022615  CompletionUsage(completion_tokens=594, prompt_...
# 2879  1763022613  CompletionUsage(completion_tokens=210, prompt_...
#
#      Cor_answer Iteration  Throughput      Cost  P@5
# 0             0         1  350.152057  0.004480  0.0
# 1             0         1  431.091144  0.003618  0.0
# 2             1         1  307.306088  0.003931  0.2
# 3             1         1  415.399059  0.003652  0.0
# 4             1         1  431.624158  0.003794  0.0
# ...         ...       ...         ...       ...  ...
# 2875          1         2  426.360021  0.015810  0.0
# 2876          1         2  435.703936  0.015284  0.0
# 2877          1         2  548.386386  0.011558  0.0
# 2878          1         2  431.140304  0.015984  0.0
# 2879          1         2  420.556492  0.013908  0.0
#
# [2880 rows x 27 columns]

# %%
metric_descriptions_df = pd.DataFrame(
    [
        {'Metric': metric, 'Description': description}
        for metric, description in metric_descriptions.items()
    ]
)
metric_descriptions_df
# Out:
#            Metric                                        Description
# 0      Cor_answer              Average correctness rate per question
# 1         Elapsed     Average wall-clock time per question (seconds)
# 2    Total_tokens         Average total tokens consumed per question
# 3             P@5  Precision@5: share of retrieved documents cont...
# 4      Throughput                Average tokens processed per second
# 5            Cost                        USD spent per iteration/run
# 6  Price-per-cost                     Cents spent per correct answer

# %%
excel_path = SUMMARY_FILE

with pd.ExcelWriter(excel_path) as writer:
    if 'Difficulty' in GROUP_BY_COLS:
        pivot_df = summary_table.set_index(GROUP_BY_COLS)[DISPLAY_COLUMNS].unstack('Difficulty')
        pivot_df.to_excel(writer, sheet_name=f'diff_topk{TOP_K}')
    else:
        summary_table_display.to_excel(writer, sheet_name=f'diff_topk{TOP_K}', index=False)

    if summary_table_no_diff is not None:
        summary_table_no_diff.to_excel(writer, sheet_name=f'overview_topk{TOP_K}', index=False)

    per_iteration_summary.to_excel(writer, sheet_name='per_iteration', index=False)
    merged_df.to_excel(writer, sheet_name='raw_data', index=False)
    metric_descriptions_df.to_excel(writer, sheet_name='Descriptions', index=False)

excel_path
# Out:
# 'results/summary_CI_topk5.xlsx'
